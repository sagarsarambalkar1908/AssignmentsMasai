# %%
import pandas as pd
df= pd.read_csv("/Users/sagar.s.sarambalkar/github/assignments/AssignmentsMasai/pandassubjective/students.csv")
# display first 3 rows
df.head(3)
#
df.describe()
df.shape
df.dtypes
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  10 non-null     int64
#  1   Name       10 non-null     str
#  2   Age        10 non-null     int64
#  3   Marks      10 non-null     int64
#  4   Grade      10 non-null     str
# dtypes: int64(3), str(2)
# memory usage: 532.0 bytes

# %%
# check data frame dimention
df.shape
# Out:
# (10, 5)

# %%
# find data type of each column
df.dtypes
# Out:
# StudentID    int64
# Name           str
# Age          int64
# Marks        int64
# Grade          str
# dtype: object

# %%
# df. describe method is used to generate summary statistics of a DataFrame or Series.
df.describe()
# Out:
#        StudentID        Age      Marks
# count   10.00000  10.000000  10.000000
# mean   105.50000  20.700000  78.800000
# std      3.02765   1.337494  11.535453
# min    101.00000  19.000000  60.000000
# 25%    103.25000  20.000000  71.250000
# 50%    105.50000  20.500000  79.000000
# 75%    107.75000  21.750000  87.250000
# max    110.00000  23.000000  95.000000
